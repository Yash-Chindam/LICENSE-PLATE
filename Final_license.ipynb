# %%
# !nvidia-smi
# Out:
# Tue Sep 24 09:56:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install roboflow
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.1/874.1 kB 20.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

display.clear_output()

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uoX3EDAy9vi9QoZCb3th")
project = rf.workspace("yash-chindam-ukt41").project("jhgv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.100, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to jhgv-1 in yolov8:: 100%|██████████| 3248/3248 [00:00<00:00, 3503.80it/s]

# %%
model = YOLO('yolov8n.pt')
results = model.train(data="/content/jhgv-1/data.yaml", epochs=50)
# Out:
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
val_results = model.val()
# Out:
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/jhgv-1/valid/labels.cache... 169 images, 0 backgrounds, 0 corrupt: 100%|██████████| 169/169 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:03<00:00,  3.58it/s]
#                    all        169        169      0.994          1      0.995      0.777
# Speed: 0.6ms preprocess, 5.1ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to runs/detect/train22

# %%
Image(filename=f'/content/runs/detect/train22/val_batch0_labels.jpg', width=600)

# %%
Image(filename=f'/content/runs/detect/train22/val_batch0_pred.jpg', width=600)

# %%
import zipfile
import os

def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                absolute_path = os.path.join(root, file)
                relative_path = os.path.relpath(absolute_path, folder_path)
                zipf.write(absolute_path, relative_path)

folder_to_zip = '/content/runs'
output_zip = '/content/LPD-runs.zip'

zip_folder(folder_to_zip, output_zip)

# %%
from google.colab import files
files.download(output_zip)

# %%
# !ls /content/jhgv-1/train  # List the images in your train folder
# !cat /content/jhgv-1/train/labels/*.txt  # Check if the annotations are correct
